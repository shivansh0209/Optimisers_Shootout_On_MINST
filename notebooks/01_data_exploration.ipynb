# %% [markdown]
# ## Objective
# 1. The main ofjective of this file is to get idea of the Fashion-MNIST dataset
# 2. Also to have a look on potential problems in the dataset.
# 3. We will also visualize the images from the dataset using the PIL library

# %%
import pandas as pd
from PIL import Image

# %%
df = pd.read_csv('../data/fashion-mnist_train.csv')

# %% [markdown]
# ### Analyzing the structure

# %%
df.shape
# Out:
# (60000, 785)

# %%
df.columns
# Out:
# Index(['label', 'pixel1', 'pixel2', 'pixel3', 'pixel4', 'pixel5', 'pixel6',
#        'pixel7', 'pixel8', 'pixel9',
#        ...
#        'pixel775', 'pixel776', 'pixel777', 'pixel778', 'pixel779', 'pixel780',
#        'pixel781', 'pixel782', 'pixel783', 'pixel784'],
#       dtype='str', length=785)

# %%
df['label'].value_counts()
# Out:
# label
# 2    6000
# 9    6000
# 6    6000
# 0    6000
# 3    6000
# 4    6000
# 5    6000
# 8    6000
# 7    6000
# 1    6000
# Name: count, dtype: int64

# %% [markdown]
# ### Checking for inconsistencies in the data

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 359.3 MB

# %%
df.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       4.500000      0.000900      0.006150      0.035333      0.101933
# std        2.872305      0.094689      0.271011      1.222324      2.452871
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        4.500000      0.000000      0.000000      0.000000      0.000000
# 75%        7.000000      0.000000      0.000000      0.000000      0.000000
# max        9.000000     16.000000     36.000000    226.000000    164.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.247967      0.411467      0.805767      2.198283      5.682000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(43)

# %% [markdown]
# ### Checking for missing values

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Sample images from the dataset

# %%
Image.frombytes(mode = 'L', size = (28, 28), data = df.iloc[4:5].values.astype('uint8'))
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %%
Image.frombytes(mode = 'L', size = (28, 28), data = df.iloc[42:43].values.astype('uint8'))
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %% [markdown]
# ## Conclusion
# 1. The pixel data doesnt contain any mising values.
# 2. It doesnt contain any inconsistencies - all values are within the pixel range.
# 3. The values need to be scaled before entering into the neural network
# 4. All classes have a balanced amount of rows in the dataset.
# 5. There are duplicated rows but there percentage is negligible so we can ignore the removal of them.
